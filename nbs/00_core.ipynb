# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(a:str):
    "wishing  a happy meditative state"
    return f' wishing {a} a happy meditative state'
    pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[12], line 2
#     import nbdev; nbdev.nbdev_export()
#
#   File ~/miniconda3/lib/python3.12/site-packages/fastcore/script.py:116 in _f
#     if not mod: return func(*args, **kwargs)
#
#   File ~/miniconda3/lib/python3.12/site-packages/nbdev/doclinks.py:160 in nbdev_export
#     _build_modidx()
#
#   File ~/miniconda3/lib/python3.12/site-packages/nbdev/doclinks.py:116 in _build_modidx
#     try: res['syms'].update(_get_modidx((dest.parent/file).resolve(), code_root, nbs_path=nbs_path))
#
#   File ~/miniconda3/lib/python3.12/site-packages/nbdev/doclinks.py:93 in _get_modidx
#     for tree in ast.parse(cell.code).body:
#
#   File ~/miniconda3/lib/python3.12/ast.py:52 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:2
# ...
